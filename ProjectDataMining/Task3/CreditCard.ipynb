# %% [markdown]
# <a href='https://www.darshan.ac.in/'> <img src='https://www.darshan.ac.in/Content/media/DU_Logo.svg' width="250" height="300"/></a>
# <pre>
# <center><b><h1>Data Mining</b></center>
# <center><b><h1>Project Work</b></center>
# <center><b><h1>137 | Vishal Baraiya | 23010101014</b></center>
# <pre>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### 1. Read Online Retail Data Set.

# %%
dt = pd.read_csv('D:\\VS_CODES\\DataMining\\ProjectDataMining\\Dataset\\BankChurners.csv',sep=',',encoding='ISO-8859-1')
dt
# Out:
#        CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0      768805383  Existing Customer            45      M                3
# 1      818770008  Existing Customer            49      F                5
# 2      713982108  Existing Customer            51      M                3
# 3      769911858  Existing Customer            40      F                4
# 4      709106358  Existing Customer            40      M                3
# ...          ...                ...           ...    ...              ...
# 10122  772366833  Existing Customer            50      M                2
# 10123  710638233  Attrited Customer            41      M                2
# 10124  716506083  Attrited Customer            44      F                1
# 10125  717406983  Attrited Customer            30      M                2
# 10126  714337233  Attrited Customer            43      F                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# ...

# %% [markdown]
# ### 2.Read First 10 Data.

# %%
dt.head(5)
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0  768805383  Existing Customer            45      M                3
# 1  818770008  Existing Customer            49      F                5
# 2  713982108  Existing Customer            51      M                3
# 3  769911858  Existing Customer            40      F                4
# 4  709106358  Existing Customer            40      M                3
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0     High School        Married     $60K - $80K          Blue
# 1        Graduate         Single  Less than $40K          Blue
# 2        Graduate        Married    $80K - $120K          Blue
# 3     High School        Unknown  Less than $40K          Blue
# 4      Uneducated        Married     $60K - $80K          Blue
#
#    Months_on_book  ...  Credit_Limit  Total_Revolving_Bal  Avg_Open_To_Buy  \
# 0              39  ...       12691.0                  777          11914.0
# ...

# %% [markdown]
# ### 3.Read Last 10 Data.

# %%
dt.tail(5)
# Out:
#        CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 10122  772366833  Existing Customer            50      M                2
# 10123  710638233  Attrited Customer            41      M                2
# 10124  716506083  Attrited Customer            44      F                1
# 10125  717406983  Attrited Customer            30      M                2
# 10126  714337233  Attrited Customer            43      F                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# 10122        Graduate         Single     $40K - $60K          Blue
# 10123         Unknown       Divorced     $40K - $60K          Blue
# 10124     High School        Married  Less than $40K          Blue
# 10125        Graduate        Unknown     $40K - $60K          Blue
# 10126        Graduate        Married  Less than $40K        Silver
#
#        Months_on_book  ...  Credit_Limit  Total_Revolving_Bal  \
# ...

# %% [markdown]
# ### 4. Summary of statiscal data

# %%
dt.describe()
# Out:
#           CLIENTNUM  Customer_Age  Dependent_count  Months_on_book  \
# count  1.012700e+04  10127.000000     10127.000000    10127.000000
# mean   7.391776e+08     46.325960         2.346203       35.928409
# std    3.690378e+07      8.016814         1.298908        7.986416
# min    7.080821e+08     26.000000         0.000000       13.000000
# 25%    7.130368e+08     41.000000         1.000000       31.000000
# 50%    7.179264e+08     46.000000         2.000000       36.000000
# 75%    7.731435e+08     52.000000         3.000000       40.000000
# max    8.283431e+08     73.000000         5.000000       56.000000
#
#        Total_Relationship_Count  Months_Inactive_12_mon  \
# count              10127.000000            10127.000000
# mean                   3.812580                2.341167
# std                    1.554408                1.010622
# min                    1.000000                0.000000
# 25%                    3.000000                2.000000
# ...

# %%
dt.describe(include='all')
# Out:
#            CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# count   1.012700e+04              10127  10127.000000  10127     10127.000000
# unique           NaN                  2           NaN      2              NaN
# top              NaN  Existing Customer           NaN      F              NaN
# freq             NaN               8500           NaN   5358              NaN
# mean    7.391776e+08                NaN     46.325960    NaN         2.346203
# std     3.690378e+07                NaN      8.016814    NaN         1.298908
# min     7.080821e+08                NaN     26.000000    NaN         0.000000
# 25%     7.130368e+08                NaN     41.000000    NaN         1.000000
# 50%     7.179264e+08                NaN     46.000000    NaN         2.000000
# 75%     7.731435e+08                NaN     52.000000    NaN         3.000000
# max     8.283431e+08                NaN     73.000000    NaN         5.000000
#
# ...

# %% [markdown]
# ### 5.Data Types of all the Columns

# %%
dt.dtypes
# Out:
# CLIENTNUM                                                                                                                               int64
# Attrition_Flag                                                                                                                         object
# Customer_Age                                                                                                                            int64
# Gender                                                                                                                                 object
# Dependent_count                                                                                                                         int64
# Education_Level                                                                                                                        object
# ...

# %% [markdown]
# ### 6. Number of Rows

# %%
dt.shape[0]
# Out:
# 10127

# %% [markdown]
# ### 7.Number of Columns

# %%
dt.shape[1]
# Out:
# 23

# %% [markdown]
# ### 8.Sum of Any Column

# %%
dt['Dependent_count'].sum()
# Out:
# 23760

# %% [markdown]
# ### 9.Average Of Any Column

# %%
dt['Dependent_count'].mean()
# Out:
# 2.3462032191172115

# %% [markdown]
# ### 10. Max in Column

# %%
dt['Dependent_count'].max()
# Out:
# 5

# %% [markdown]
# ### 11.Min in Columns

# %%
dt['Dependent_count'].min()
# Out:
# 0

# %% [markdown]
# ### 12.Standard deviation of column

# %%
dt['Dependent_count'].std()
# Out:
# 1.2989083489037916

# %% [markdown]
# ### 13.location of column using iloc

# %%
dt.iloc[3]
# Out:
# CLIENTNUM                                                                                                                                     769911858
# Attrition_Flag                                                                                                                        Existing Customer
# Customer_Age                                                                                                                                         40
# Gender                                                                                                                                                F
# Dependent_count                                                                                                                                       4
# Education_Level                                                                                                                             High School
# ...

# %% [markdown]
# ### 14.copy

# %%
x=dt.copy()
x
# Out:
#        CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0      768805383  Existing Customer            45      M                3
# 1      818770008  Existing Customer            49      F                5
# 2      713982108  Existing Customer            51      M                3
# 3      769911858  Existing Customer            40      F                4
# 4      709106358  Existing Customer            40      M                3
# ...          ...                ...           ...    ...              ...
# 10122  772366833  Existing Customer            50      M                2
# 10123  710638233  Attrited Customer            41      M                2
# 10124  716506083  Attrited Customer            44      F                1
# 10125  717406983  Attrited Customer            30      M                2
# 10126  714337233  Attrited Customer            43      F                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# ...

# %% [markdown]
# ### 15.Uniqu data

# %%
dt['Dependent_count'].nunique()
# Out:
# 6

# %% [markdown]
# ### 16.Histogram of Age

# %%
dt['Dependent_count'].hist(edgecolor = 'black')
plt.title("Histogram of Age")
plt.xlabel('Dependent_count')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ### 17.return value having 424 quantity

# %%
q_counts = dt['Dependent_count'].value_counts()
q_counts[q_counts == 424]
# Out:
# Dependent_count
# 5    424
# Name: count, dtype: int64

# %% [markdown]
# ### 19.drop

# %%
dt.drop("Dependent_count", axis=1, inplace=True)

# %%
dt
# Out:
#        CLIENTNUM     Attrition_Flag  Customer_Age Gender Education_Level  \
# 0      768805383  Existing Customer            45      M     High School
# 1      818770008  Existing Customer            49      F        Graduate
# 2      713982108  Existing Customer            51      M        Graduate
# 3      769911858  Existing Customer            40      F     High School
# 4      709106358  Existing Customer            40      M      Uneducated
# ...          ...                ...           ...    ...             ...
# 10122  772366833  Existing Customer            50      M        Graduate
# 10123  710638233  Attrited Customer            41      M         Unknown
# 10124  716506083  Attrited Customer            44      F     High School
# 10125  717406983  Attrited Customer            30      M        Graduate
# 10126  714337233  Attrited Customer            43      F        Graduate
#
#       Marital_Status Income_Category Card_Category  Months_on_book  \
# ...

# %% [markdown]
# ### 18.Condition

# %%
dt[dt["Gender"] == 'M']
# Out:
#        CLIENTNUM     Attrition_Flag  Customer_Age Gender Education_Level  \
# 0      768805383  Existing Customer            45      M     High School
# 2      713982108  Existing Customer            51      M        Graduate
# 4      709106358  Existing Customer            40      M      Uneducated
# 5      713061558  Existing Customer            44      M        Graduate
# 6      810347208  Existing Customer            51      M         Unknown
# ...          ...                ...           ...    ...             ...
# 10118  713755458  Attrited Customer            50      M         Unknown
# 10120  710841183  Existing Customer            54      M     High School
# 10122  772366833  Existing Customer            50      M        Graduate
# 10123  710638233  Attrited Customer            41      M         Unknown
# 10125  717406983  Attrited Customer            30      M        Graduate
#
#       Marital_Status Income_Category Card_Category  Months_on_book  \
# ...

# %% [markdown]
# ### 20.length

# %%
len(dt[dt["Gender"] == 1])
# Out:
# 0

# %% [markdown]
# ### 21.Groupby

# %%
quant = dt.groupby('Gender')['Customer_Age'].sum()
total = quant[quant > 100]
total
# Out:
# Gender
# F    248916
# M    220227
# Name: Customer_Age, dtype: int64

# %% [markdown]
# ### 22.return Index

# %%
dt.index
# Out:
# RangeIndex(start=0, stop=10127, step=1)

# %% [markdown]
# ### 23.return highest column value

# %%
dt['CLIENTNUM'].value_counts().head(1)
# Out:
# CLIENTNUM
# 768805383    1
# Name: count, dtype: int64

# %% [markdown]
# ### 24.using loc

# %%
dt.loc[1,'CLIENTNUM']
# Out:
# 818770008

# %% [markdown]
# ### 25.set Index

# %%
dt.set_index('CLIENTNUM')
# Out:
#               Attrition_Flag  Customer_Age Gender Education_Level  \
# CLIENTNUM
# 768805383  Existing Customer            45      M     High School
# 818770008  Existing Customer            49      F        Graduate
# 713982108  Existing Customer            51      M        Graduate
# 769911858  Existing Customer            40      F     High School
# 709106358  Existing Customer            40      M      Uneducated
# ...                      ...           ...    ...             ...
# 772366833  Existing Customer            50      M        Graduate
# 710638233  Attrited Customer            41      M         Unknown
# 716506083  Attrited Customer            44      F     High School
# 717406983  Attrited Customer            30      M        Graduate
# 714337233  Attrited Customer            43      F        Graduate
#
#           Marital_Status Income_Category Card_Category  Months_on_book  \
# CLIENTNUM
# 768805383        Married     $60K - $80K          Blue              39
# ...
