# %% [markdown]
# <a href='https://www.darshan.ac.in/'> <img src='https://www.darshan.ac.in/Content/media/DU_Logo.svg' width="250" height="300"/></a>
# <pre>
# <center><b><h1>Data Mining</b></center>
# <center><b><h1>Project Work</b></center>
# <center><b><h1>137 | Vishal Baraiya | 23010101014</b></center>
# <pre>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### 1. Read Online Retail Data Set.

# %%
dt = pd.read_csv('D:\\VS_CODES\\DataMining\\ProjectDataMining\\Dataset\\Heart.csv',sep=',',encoding='ISO-8859-1')
dt
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %% [markdown]
# ### 2.Read First 10 Data.

# %%
dt.head(10)
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
# 5   58    0   0       100   248    0        0      122      0      1.0      1
# 6   58    1   0       114   318    0        2      140      0      4.4      0
# 7   55    1   0       160   289    0        0      145      1      0.8      1
# 8   46    1   0       120   249    0        0      144      0      0.8      2
# 9   54    1   0       122   286    0        0      116      1      3.2      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# ...

# %% [markdown]
# ### 3.Read Last 10 Data.

# %%
dt.tail(10)
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 1015   58    1   0       128   216    0        0      131      1      2.2
# 1016   65    1   3       138   282    1        0      174      0      1.4
# 1017   53    1   0       123   282    0        1       95      1      2.0
# 1018   41    1   0       110   172    0        0      158      0      0.0
# 1019   47    1   0       112   204    0        1      143      0      0.1
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 1015      1   3     3       0
# 1016      1   1     2       0
# 1017      1   2     3       0
# ...

# %% [markdown]
# ### 4. Summary of statiscal data

# %%
dt.describe()
# Out:
#                age          sex           cp     trestbps        chol  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.00000
# mean     54.434146     0.695610     0.942439   131.611707   246.00000
# std       9.072290     0.460373     1.029641    17.516718    51.59251
# min      29.000000     0.000000     0.000000    94.000000   126.00000
# 25%      48.000000     0.000000     0.000000   120.000000   211.00000
# 50%      56.000000     1.000000     1.000000   130.000000   240.00000
# 75%      61.000000     1.000000     2.000000   140.000000   275.00000
# max      77.000000     1.000000     3.000000   200.000000   564.00000
#
#                fbs      restecg      thalach        exang      oldpeak  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.000000
# mean      0.149268     0.529756   149.114146     0.336585     1.071512
# std       0.356527     0.527878    23.005724     0.472772     1.175053
# ...

# %%
dt.describe(include='all')
# Out:
#                age          sex           cp     trestbps        chol  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.00000
# mean     54.434146     0.695610     0.942439   131.611707   246.00000
# std       9.072290     0.460373     1.029641    17.516718    51.59251
# min      29.000000     0.000000     0.000000    94.000000   126.00000
# 25%      48.000000     0.000000     0.000000   120.000000   211.00000
# 50%      56.000000     1.000000     1.000000   130.000000   240.00000
# 75%      61.000000     1.000000     2.000000   140.000000   275.00000
# max      77.000000     1.000000     3.000000   200.000000   564.00000
#
#                fbs      restecg      thalach        exang      oldpeak  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.000000
# mean      0.149268     0.529756   149.114146     0.336585     1.071512
# std       0.356527     0.527878    23.005724     0.472772     1.175053
# ...

# %% [markdown]
# ### 5.Data Types of all the Columns

# %%
dt.dtypes
# Out:
# age           int64
# sex           int64
# cp            int64
# trestbps      int64
# chol          int64
# fbs           int64
# restecg       int64
# thalach       int64
# exang         int64
# oldpeak     float64
# slope         int64
# ca            int64
# thal          int64
# target        int64
# dtype: object

# %% [markdown]
# ### 6. Number of Rows

# %%
dt.shape[0]
# Out:
# 1025

# %% [markdown]
# ### 7.Number of Columns

# %%
dt.shape[1]
# Out:
# 14

# %% [markdown]
# ### 8.Sum of Any Column

# %%
dt['sex'].sum()
# Out:
# 713

# %% [markdown]
# ### 9.Average Of Any Column

# %%
dt['sex'].mean()
# Out:
# 0.6956097560975609

# %% [markdown]
# ### 10. Max in Column

# %%
dt['age'].max()
# Out:
# 77

# %% [markdown]
# ### 11.Min in Columns

# %%
dt['age'].min()
# Out:
# 29

# %% [markdown]
# ### 12.Standard deviation of column

# %%
dt['age'].std()
# Out:
# 9.072290233244281

# %% [markdown]
# ### 13.location of column using iloc

# %%
dt.iloc[3]
# Out:
# age          61.0
# sex           1.0
# cp            0.0
# trestbps    148.0
# chol        203.0
# fbs           0.0
# restecg       1.0
# thalach     161.0
# exang         0.0
# oldpeak       0.0
# slope         2.0
# ca            1.0
# thal          3.0
# target        0.0
# Name: 3, dtype: float64

# %% [markdown]
# ### 14.copy

# %%
x = dt.copy()
x
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %% [markdown]
# ### 15.Unique data

# %%
dt['fbs'].nunique()
# Out:
# 2

# %% [markdown]
# ### 16.Histogram of Age

# %%
dt['age'].hist(edgecolor = 'black')
plt.title("Histogram of Age")
plt.xlabel('age')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ### 17.return value having 6 quantity

# %%
q_counts = dt['age'].value_counts()
q_counts[q_counts == 6]
# Out:
# age
# 37    6
# 34    6
# Name: count, dtype: int64

# %% [markdown]
# ### 19.drop

# %%
dt.drop("cp", axis=1, inplace=True)

# %%
dt
# Out:
#       age  sex  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0      52    1       125   212    0        1      168      0      1.0      2
# 1      53    1       140   203    1        0      155      1      3.1      0
# 2      70    1       145   174    0        1      125      1      2.6      0
# 3      61    1       148   203    0        1      161      0      0.0      2
# 4      62    0       138   294    1        1      106      0      1.9      1
# ...   ...  ...       ...   ...  ...      ...      ...    ...      ...    ...
# 1020   59    1       140   221    0        1      164      1      0.0      2
# 1021   60    1       125   258    0        0      141      1      2.8      1
# 1022   47    1       110   275    0        0      118      1      1.0      1
# 1023   50    0       110   254    0        0      159      0      0.0      2
# 1024   54    1       120   188    0        1      113      0      1.4      1
#
#       ca  thal  target
# ...

# %% [markdown]
# ### 18.Condition

# %%
dt[dt["sex"] == 1]
# Out:
#       age  sex  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0      52    1       125   212    0        1      168      0      1.0      2
# 1      53    1       140   203    1        0      155      1      3.1      0
# 2      70    1       145   174    0        1      125      1      2.6      0
# 3      61    1       148   203    0        1      161      0      0.0      2
# 6      58    1       114   318    0        2      140      0      4.4      0
# ...   ...  ...       ...   ...  ...      ...      ...    ...      ...    ...
# 1019   47    1       112   204    0        1      143      0      0.1      2
# 1020   59    1       140   221    0        1      164      1      0.0      2
# 1021   60    1       125   258    0        0      141      1      2.8      1
# 1022   47    1       110   275    0        0      118      1      1.0      1
# 1024   54    1       120   188    0        1      113      0      1.4      1
#
#       ca  thal  target
# ...

# %% [markdown]
# ### 20.length

# %%
len(dt[dt["age"] == 2])
# Out:
# 0

# %% [markdown]
# ### 21.Groupby

# %%
quant = dt.groupby('sex')['age'].sum()
total = quant[quant > 100]
total
# Out:
# sex
# 0    17425
# 1    38370
# Name: age, dtype: int64

# %% [markdown]
# ### 22.return Index

# %%
dt.index
# Out:
# RangeIndex(start=0, stop=1025, step=1)

# %% [markdown]
# ### 23.return highest column value

# %%
dt['age'].value_counts().head(1)
# Out:
# age
# 58    68
# Name: count, dtype: int64

# %% [markdown]
# ### 24.using loc

# %%
dt.loc[1,'age']
# Out:
# 53

# %% [markdown]
# ### 25.set Index

# %%
dt.set_index('age')
# Out:
#      sex  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  ca  \
# age
# 52     1       125   212    0        1      168      0      1.0      2   2
# 53     1       140   203    1        0      155      1      3.1      0   0
# 70     1       145   174    0        1      125      1      2.6      0   0
# 61     1       148   203    0        1      161      0      0.0      2   1
# 62     0       138   294    1        1      106      0      1.9      1   3
# ..   ...       ...   ...  ...      ...      ...    ...      ...    ...  ..
# 59     1       140   221    0        1      164      1      0.0      2   0
# 60     1       125   258    0        0      141      1      2.8      1   1
# 47     1       110   275    0        0      118      1      1.0      1   1
# 50     0       110   254    0        0      159      0      0.0      2   0
# 54     1       120   188    0        1      113      0      1.4      1   1
#
#      thal  target
# age
# 52      3       0
# ...
